# %% [markdown]
# # 02_Normal_Distribution_Test

# %% [markdown]
# ###Continuous Data:
#
# The data should be continuous, meaning it can take any value within a range.
#
# Examples include height, weight, temperature, or time.
#
# ###Interval or Ratio Scale:
#
# The data should be on an interval or ratio scale.
#
# Interval scales have meaningful differences between values but no true zero point (e.g., temperature in Celsius).
#
# Ratio scales have both meaningful differences and a true zero point (e.g., weight).

# %% [markdown]
# # import librares

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # load the data

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Graphical representation

# %%
Graph=sns.histplot(data=df, x="tip", hue="size", kde=True);
Graph
# Out:
# C:\Users\ustb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ## Shapiro wilk test on normal distribution or Gaussion Distribution
# ### Null Hypothesis: The data is Normaly Distributed
# ### Alternative Hypothesis: the data is not Normaly Distributed

# %%
# Shapiro wilk test

statistics, p= stats.shapiro(df["total_bill"])
#print the result using if condition
if p>0.05:
    print(f'p_value: {p}, sample looks Guassion/Normaly distributed (fail to reject H0)')
else:
    print(f'p_value: {p}, sample looks does not Guassion/Normaly distributed (reject H0)')
# Out:
# p_value: 3.3244529351605934e-10, sample looks does not Guassion/Normaly distributed (reject H0)

# %%
statistics, p= stats.shapiro(df["total_bill"])
#print the result using if condition
if p>0.05:
    print(f'p_value: {p}, sample looks Guassion/Normaly distributed (fail to reject H0)')
else:
    print(f'p_value: {p}, sample looks does not Guassion/Normaly distributed (reject H0)')
# Out:
# p_value: 3.3244529351605934e-10, sample looks does not Guassion/Normaly distributed (reject H0)

# %%
sns.histplot(data=df, x='total_bill', kde=True)
# Out:
# C:\Users\ustb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>
